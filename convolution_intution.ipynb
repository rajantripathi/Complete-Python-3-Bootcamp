# %% [markdown]
# <a href="https://colab.research.google.com/github/rajantripathi/Complete-Python-3-Bootcamp/blob/master/convolution_intution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.signal import convolve2d
from skimage.data import coffee
from skimage import color
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.imshow(coffee())

# %%
img=color.rgb2gray(coffee())
plt.imshow(img)
plt.axis('off')
# Out:
# (-0.5, 599.5, 399.5, -0.5)

# %% [markdown]
# Defining Kernels

# %%
kernel_edge_detect1= np.array([[1.,0., -1],
                             [0.,0.,0.],
                             [-1,0.,1.]])

kernel_edge_detect2 = np.array([[0.,1. ,0.],
                             [1.,-4.,1.],
                             [0,1.,0.]])

kernel_edge_detect3 = np.array([[-1.,-1., -1],
                             [-1.,-8.,1.],
                             [-1,-1.,-1.]])

# %%
img_edge1 = convolve2d(img ,kernel_edge_detect1 , 'valid')
plt.imshow(img_edge1 , cmap = plt.cm.gray)
plt.axis('off')
plt.show()

# %%
img_edge2 = convolve2d(img , kernel_edge_detect2)
plt.imshow(img_edge2 , cmap = plt.cm.gray)

# %%
img_edge3 = convolve2d(img , kernel_edge_detect3 , 'valid')
plt.imshow(img_edge2 , cmap = plt.cm.gray)
